# %%
from models import *
import numpy as npy
import scipy
import scipy.misc
import matplotlib.pyplot as plt
from skimage.restoration import denoise_tv_chambolle
from PIL import Image
from utils.common_utils import *

noisy_image_path = "C:\\Users\\Leo\\Desktop\\FinalYearProject\\DIP_remote_fusion_as.jpg"
noisy_image_pil = Image.open(noisy_image_path)
noisy_image_np = pil_to_np(noisy_image_pil)
img = plt.imshow(noisy_image_pil)

# %%
tv_denoised = denoise_tv_chambolle(noisy_image_np,weight=0.5)
result_np = tv_denoised[0]
print(result_np)
img2 = plt.imshow(result_np,cmap='gray')
# Out:
# [[0.02339393 0.02361085 0.02404732 ... 0.69214845 0.6917145  0.6914945 ]
#  [0.02334555 0.02356245 0.02399875 ... 0.69249886 0.6920671  0.6918487 ]
#  [0.02325026 0.02346706 0.02390295 ... 0.6931976  0.69277436 0.6925603 ]
#  ...
#  [0.4576836  0.46116754 0.46869266 ... 0.28587908 0.28272772 0.28121236]
#  [0.461656   0.46501014 0.4724128  ... 0.28609458 0.2829234  0.28139997]
#  [0.46364248 0.4669584  0.47431213 ... 0.28620505 0.28302598 0.28149927]]
